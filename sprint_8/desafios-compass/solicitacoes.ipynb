# %%
import requests
import pandas as pd
from IPython.display import display

api_key = "51abe1a6ded0b0e4a3fb5ffe4048ea17"
url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=pt-BR"

response = requests.get(url)
data = response.json()

filmes = []

for movie in data['results']:
    df = {'Titulo': movie['title'],
    'Data de lançamento': movie['release_date'],
    'Visão geral': movie['overview'],
    'Votos': movie['vote_count'],
    'Média de votos:': movie['vote_average']}
    filmes.append(df)

df = pd.DataFrame(filmes)
display(df)
# Out:
#                                    Titulo Data de lançamento  \
# 0                   Um Sonho de Liberdade         1994-09-23
# 1                       O Poderoso Chefão         1972-03-14
# 2             O Poderoso Chefão: Parte II         1974-12-20
# 3                    A Lista de Schindler         1993-12-15
# 4                12 Homens e uma Sentença         1957-04-10
# 5                     A Viagem de Chihiro         2001-07-20
# 6               Dilwale vai levar a noiva         1995-10-20
# 7          Batman: O Cavaleiro das Trevas         2008-07-16
# 8                  À Espera de um Milagre         1999-12-10
# 9                                Parasita         2019-05-30
# 10                             Your Name.         2016-08-26
# 11       Pulp Fiction: Tempo de Violência         1994-09-10
# 12   O Senhor dos Anéis: O Retorno do Rei         2003-12-01
# 13  Forrest Gump: O Contador de Histórias         1994-06-23
# 14                   Os Bons Companheiros         1990-09-12
# 15                Três Homens em Conflito         1966-12-22
# 16                 O Túmulo dos Vagalumes         1988-04-16
# 17                          A Vida é Bela         1997-12-20
# 18                       Os Sete Samurais         1954-04-26
# 19                        Cinema Paradiso         1988-11-17
#
#                                           Visão geral  Votos  Média de votos:
# 0   Em 1946, Andy Dufresne, um banqueiro jovem e b...  25573            8.709
# 1   Em 1945, Don Corleone é o chefe de uma mafiosa...  19445            8.705
# 2   Após a máfia matar sua família, o jovem Vito f...  11733            8.587
# 3   O alemão Oskar Schindler viu na mão de obra ju...  15124            8.569
# 4   Um jovem porto-riquenho é acusado do brutal cr...   8036            8.500
# 5   Chihiro e seus pais estão se mudando para uma ...  15531            8.540
# 6   Raj e Simran são dois jovens indianos vivendo ...   4337            8.536
# 7   Após dois anos desde o surgimento do Batman, o...  31457            8.515
# 8   Milagres acontecem em lugares inesperados, mes...  16493            8.509
# 9   Toda a família de Ki-taek está desempregada, v...  17105            8.510
# 10  Mitsuha é a filha do prefeito de uma pequena c...  10753            8.498
# 11  Vincent Vega e Jules Winnfield são dois assass...  26654            8.489
# 12  O confronto final entre as forças do bem e do ...  23033            8.477
# 13  Quarenta anos da história dos Estados Unidos, ...  26178            8.477
# 14  Um jovem cresce na máfia e trabalha arduamente...  12152            8.467
# 15  Durante o auge da Guerra Civil, um misterioso ...   8080            8.467
# 16  O filme relata a história de dois irmãos, Seit...   5105            8.459
# 17  Durante a Segunda Guerra Mundial na Itália, o ...  12568            8.454
# 18  No século XVI, durante a era Sengoku, quando o...   3399            8.454
# 19  Um diretor de cinema lembra como, em sua infân...   4115            8.453
